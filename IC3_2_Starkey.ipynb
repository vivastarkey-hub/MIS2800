# %% [markdown]
# <a href="https://colab.research.google.com/github/vivastarkey-hub/MIS2800/blob/main/IC3_2_Starkey.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#install the first library needed for SQLite3 to work using SQLite Magic
# !pip install --upgrade pandas ipython-sql prettytable==3.10.1

# %%
#install the SQL extension.
# !pip install ipython-sql
print("ipython sql installed")
# Out:
# ...
# ipython sql installed

# %%
#load the SQL magic extension
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
import sqlite3
print("sqlite3 imported")
# Out:
# sqlite3 imported

# %%
#this creates a brand-new, empty database file named 'AdCampaigns2026.db'
conn = sqlite3.connect('SuperBowl_Finance.db')
print("SuperBowl_Finance database created")
# Out:
# SuperBowl_Finance database created

# %%
#This is required so Colab stops acting like Python and acts more like a SQL database terminal
# %sql sqlite:///SuperBowl_Finance.db

# %%
# %%sql
# CREATE TABLE IF NOT EXISTS stock_performance (
#     ticker TEXT,
#     price_before_game REAL,
#     price_week_after_game REAL,
#     trading_volume_millions INTEGER
# ) STRICT;
# Out:
#  * sqlite:///SuperBowl_Finance.db
# Done.
# []

# %%
# %%sql
# INSERT INTO stock_performance (ticker, price_before_game, price_week_after_game, trading_volume_millions)
# VALUES
#   ('PEP', 168.50, 172.10, 45),
#   ('GOOGL', 142.80, 145.20,110),
#   ('AMZN', 170.20, 178.45, 95),
#   ('VZ', 40.10, 39.85, 60),
#   ('TSLA', 190.00, 185.20, 150),
#   ('TMUS', 197.68, 199.34, 100),
#   ('STLA', 22.40, 23.10, 15);
# Out:
#  * sqlite:///SuperBowl_Finance.db
# 7 rows affected.
# []

# %%
# %%sql
# CREATE TABLE IF NOT EXISTS ad_buys (
#   ticker TEXT PRIMARY KEY,
#   company_name TEXT,
#   ad_cost_millions REAL,
#   airtime_seconds INTEGER
# ) STRICT;
# Out:
#  * sqlite:///SuperBowl_Finance.db
# Done.
# []

# %%
# %%sql
# INSERT or REPLACE INTO ad_buys (ticker, company_name, ad_cost_millions, airtime_seconds)
# VALUES
#   ('PEP', 'PepsiCo', 7.0, 3.0),
#   ('GOOGL', 'Google', 14.0, 60),
#   ('AMZN', 'Amazon', 14.0, 60),
#   ('VZ', 'Verizon', 7.0, 30),
#   ('TSLA', 'Tesla', 0, 0),
#   ('TMUS', 'T-Mobile', 10.0, 30),
#   ('STLA', 'Setllantis (Jeep)', 6.5, 30);
# Out:
#  * sqlite:///SuperBowl_Finance.db
# 7 rows affected.
# []

# %%
# %%sql
# SELECT * FROM stock_performance;
# Out:
#  * sqlite:///SuperBowl_Finance.db
# Done.
# [('PEP', 168.5, 172.1, 45),
#  ('GOOGL', 142.8, 145.2, 110),
#  ('AMZN', 170.2, 178.45, 95),
#  ('VZ', 40.1, 39.85, 60),
#  ('TSLA', 190.0, 185.2, 150),
#  ('TMUS', 197.68, 199.34, 100),
#  ('STLA', 22.4, 23.1, 15)]

# %%
# %%sql
# SELECT ticker, price_before_game FROM stock_performance ORDER BY ticker ASC
# Out:
#  * sqlite:///SuperBowl_Finance.db
# Done.
# [('AMZN', 170.2),
#  ('GOOGL', 142.8),
#  ('PEP', 168.5),
#  ('STLA', 22.4),
#  ('TMUS', 197.68),
#  ('TSLA', 190.0),
#  ('VZ', 40.1)]

# %%
# %%sql
# SELECT * FROM stock_performance WHERE ticker LIKE 'T%'
# Out:
#  * sqlite:///SuperBowl_Finance.db
# Done.
# [('TSLA', 190.0, 185.2, 150), ('TMUS', 197.68, 199.34, 100)]

# %%
# %%sql
# SELECT ticker, price_week_after_game FROM stock_performance WHERE price_week_after_game > 150
# Out:
#  * sqlite:///SuperBowl_Finance.db
# Done.
# [('PEP', 172.1), ('AMZN', 178.45), ('TSLA', 185.2), ('TMUS', 199.34)]

# %%
# %%sql
# SELECT * FROM ad_buys;
# Out:
#  * sqlite:///SuperBowl_Finance.db
# Done.
# [('PEP', 'PepsiCo', 7.0, 3),
#  ('GOOGL', 'Google', 14.0, 60),
#  ('AMZN', 'Amazon', 14.0, 60),
#  ('VZ', 'Verizon', 7.0, 30),
#  ('TSLA', 'Tesla', 0.0, 0),
#  ('TMUS', 'T-Mobile', 10.0, 30),
#  ('STLA', 'Setllantis (Jeep)', 6.5, 30)]

# %%
# %%sql
# SELECT ticker, company_name FROM ad_buys ORDER BY company_name DESC
# Out:
#  * sqlite:///SuperBowl_Finance.db
# Done.
# [('VZ', 'Verizon'),
#  ('TSLA', 'Tesla'),
#  ('TMUS', 'T-Mobile'),
#  ('STLA', 'Setllantis (Jeep)'),
#  ('PEP', 'PepsiCo'),
#  ('GOOGL', 'Google'),
#  ('AMZN', 'Amazon')]

# %%
# %%sql
# SELECT ticker, airtime_seconds FROM ad_buys WHERE ticker LIKE 'T%' AND airtime_seconds = 0
# Out:
#  * sqlite:///SuperBowl_Finance.db
# Done.
# [('TSLA', 0)]
