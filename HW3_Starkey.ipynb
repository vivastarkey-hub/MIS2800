# %% [markdown]
# <a href="https://colab.research.google.com/github/vivastarkey-hub/MIS2800/blob/main/HW3_Starkey.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install --upgrade pandas ipython-sql prettytable==3.10.1

# %%
# !pip install ipython-sql
print ('ipython sql installed')
# Out:
# ...
# ipython sql installed

# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
import sqlite3
print("sqlite3 imported")
# Out:
# sqlite3 imported

# %%
conn=sqlite3.connect('AdCampaigns2026.db')
print("database created")
# Out:
# database created

# %%
# %sql sqlite:///AdCampaigns2026.db

# %%
#Block 1
# %%sql
CREATE TABLE IF NOT EXISTS marketing_brands (
    brand_id INTEGER PRIMARY KEY,
    brand_name TEXT,
    brand_type TEXT,
    brand_budget INTEGER
) STRICT;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# []

# %%
#Block 2
# %%sql
INSERT or REPLACE INTO marketing_brands (brand_id, brand_name, brand_type, brand_budget)
VALUES
    (1, 'Doritos', 'Snacks', 7000000),
    (2, 'AWS', 'Technology', 15000000),
    (3, 'Pepsi', 'Beverages', 2000000),
    (4, 'He_Gets_Us', 'Religious', 1000000),
    (5, 'Dr_Pepper', 'Beverages', 5000000),
    (6, 'IBM', 'Technology', 100000),
    (7, 'Google', 'Technology', 8000000);
# Out:
#  * sqlite:///AdCampaigns2026.db
# 7 rows affected.
# []

# %%
#Block 3
# %%sql
SELECT * FROM marketing_brands
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [(1, 'Doritos', 'Snacks', 7000000),
#  (2, 'AWS', 'Technology', 15000000),
#  (3, 'Pepsi', 'Beverages', 2000000),
#  (4, 'He_Gets_Us', 'Religious', 1000000),
#  (5, 'Dr_Pepper', 'Beverages', 5000000),
#  (6, 'IBM', 'Technology', 100000),
#  (7, 'Google', 'Technology', 8000000)]

# %%
#Block 4
# %%sql
SELECT brand_name, brand_type FROM marketing_brands WHERE brand_budget > 700000
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [('Doritos', 'Snacks'),
#  ('AWS', 'Technology'),
#  ('Pepsi', 'Beverages'),
#  ('He_Gets_Us', 'Religious'),
#  ('Dr_Pepper', 'Beverages'),
#  ('Google', 'Technology')]

# %%
#Block 5
# %%sql
SELECT * FROM marketing_brands WHERE brand_type = "Religious"
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [(4, 'He_Gets_Us', 'Religious', 1000000)]

# %%
#Block 6
# %%sql
SELECT brand_name FROM marketing_brands WHERE brand_budget < 1000000
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [('IBM',)]

# %%
#Block 7
# %%sql
SELECT * FROM marketing_brands WHERE brand_budget > 7000000
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [(2, 'AWS', 'Technology', 15000000), (7, 'Google', 'Technology', 8000000)]

# %%
#Block 8
# %%sql
SELECT brand_name FROM marketing_brands WHERE brand_type = 'Snacks' OR brand_type = 'Beverages';
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [('Doritos',), ('Pepsi',), ('Dr_Pepper',)]

# %%
#Block 9
# %%sql
SELECT brand_name, brand_budget FROM marketing_brands ORDER BY brand_budget DESC
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [('AWS', 15000000),
#  ('Google', 8000000),
#  ('Doritos', 7000000),
#  ('Dr_Pepper', 5000000),
#  ('Pepsi', 2000000),
#  ('He_Gets_Us', 1000000),
#  ('IBM', 100000)]

# %%
#Block 10
# %%sql
SELECT * FROM marketing_brands ORDER BY brand_budget ASC
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [(6, 'IBM', 'Technology', 100000),
#  (4, 'He_Gets_Us', 'Religious', 1000000),
#  (3, 'Pepsi', 'Beverages', 2000000),
#  (5, 'Dr_Pepper', 'Beverages', 5000000),
#  (1, 'Doritos', 'Snacks', 7000000),
#  (7, 'Google', 'Technology', 8000000),
#  (2, 'AWS', 'Technology', 15000000)]

# %% [markdown]
# 1. How did you fix the error in Block #1? Answer: CREATE TABLE IF NOT EXISTS
# 2. How did you fix the error in Block #2? Answer:  or REPLACE INTO
# 3. How did you fix the error in Block #3? Answer: SELECT * FROM
# 4. How did you fix the error in Block #4? Answer: brand_name, brand_type FROM and add the WHERE feautres
# 5. How did you fix the error in Block #5? Answer: add WHERE
# 6. How did you fix the error in Block #6? Answer:add brand_name and WHERE
# 7. How did you fix the error in Block #7? Answer: add %%sql
# 8. How did you fix the error in Block #8? Answer:add brand_name WHERE and OR
# 9. How did you fix the error in Block #9? Answer: add brand_name and brand_budget and ORDER BY DESC
# 10. How did you fix the error in Block #10? Answer: SELECT*FROM ORDER BY ASC
