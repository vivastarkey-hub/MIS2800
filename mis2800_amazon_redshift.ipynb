# %% [markdown]
# <a href="https://colab.research.google.com/github/vivastarkey-hub/MIS2800/blob/main/mis2800_amazon_redshift.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Part 1: The Business Impact (Lyft Case Study)

# %% [markdown]
# **Lyft Video**: https://aws.amazon.com/solutions/case-studies/lyft/
#
# **Watch the Lyft video and consider the following:**
#
# 1. The Innovation: How did moving from simple data storage to a Redshift data warehouse allow Lyft to transition from "just tracking rides" to "creating new products" like Lyft Line?
#
#
# 2. Real-time vs. Strategic: Lyft uses different tools for their app (OLTP) than they do for their planning (OLAP). Why can't they just use the same database for both?

# %% [markdown]
# ## YOUR ANSWERS TO PART 1 BELOW

# %% [markdown]
# Question 1: Autoscaling allows them to scale down on infrastructure when they don't need to pay for it. In addition, the launch of Lyft line was possible because the data scientist team analyzed data in redshift looking at what would be possible in new transportation modes. They found that a lot of rides during peak ride times where going to similar places, and thus the idea for ride shares was pitched.
#
#
# Question 2: OLTP is used for Lyft's app because it has to handle millions of small data processings quickly. When you request a ride, only one row of data needs to be changed, your status. OLAP is used in decision making and analysis within Lyft when an engineer or data analyst wants to know something like the average wait time in Chicago, which requires data analysis of several rows within a database.

# %% [markdown]
# ## Part 2: The Infrastructure (AWS Skill Builder)
#
# **Instructions**
#
#
# 1.   Create a free AWS Skill Builder account https://scribehow.com/viewer/AWS_Skillbuilder_and_Eduate__Souc1HOKQbiiJnktuVgSEQ
# 2.   Complete the "Introduction" and "Architecture" modules in AWS Skill Builder. Instructions are here: https://www.loom.com/share/530dd0536c2c44729fe9a6ed26f7f162
#
# # Answer the Questions
#
# 1. Scaling the Design: In DataCamp, we practiced Normalization. In the Redshift architecture, why is "Columnar Storage" often more important for an analyst than having perfectly normalized tables? https://docs.aws.amazon.com/redshift/latest/dg/c_columnar_storage_disk_mem_mgmnt.html
#
# 2. Speed to Insight: How does the architecture of a "Leader Node" and "Compute Nodes" change how quickly a Business Intelligence report is generated?  https://docs.aws.amazon.com/redshift/latest/dg/c_high_level_system_architecture.html

# %% [markdown]
# ## YOUR ANSWERS TO PART 2 BELOW

# %% [markdown]
# Question 1: Columnar cloud data warehouse can run complex analytical queries on large datasets through massively parallel processing (MPP) technology. Columnar storage prioritizes speed of discovery over storage capacity (unlike normalized tables).
#
# Question 2: Leader nodes distribute SQL statments to the comput nodes. The compute nodes then run the code and send periodic results back to the leader node.

# %% [markdown]
# ## Part 3: Strategic Reflection
#
# 1. The Management Perspective: As a future business leader, how does knowing the capabilities of a tool like Redshift change the questions you would ask your data team?
#
# 2. The ETL Bridge: Reflect on the ETL process. If you were a manager at an organization, why is the "Clean and Load" phase the most critical part of your BI strategy?

# %% [markdown]
# ## YOUR ANSWERS TO PART 3 BELOW

# %% [markdown]
# Question 1: Redshift seems like a wonderful tool that only enhances the capabilities of a data team. I may ask my team to regularly interact with Redshift with the goal of coming up with new ways the company can expand and enhance it's offerings (mimicing Lyft's success).
#
# Question 2: The "Clean and Load" phase of the ETL process is essentially a company's quality control. This part of the process enforces universal definitions for BI dashboards so that there aren't duplicate data entries, ensuring reliable data output for analysis.
